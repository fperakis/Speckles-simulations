# %% [markdown]
# # Simulating a spleckle pattern with noise

# %% [markdown]
# Use random phasors (see Goodman - Speckle phenomena) to simulate a speckle pattern

# %%
import matplotlib.pyplot as plt
import numpy as np
from speckle_routines import *
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-abe67d33b5be> in <module>()
#       1 import matplotlib.pyplot as plt
#       2 import numpy as np
# ----> 3 from speckle_routines import *
#
# ImportError: No module named speckle_routines
