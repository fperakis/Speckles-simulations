# %% [markdown]
# # Speckle pattern, intensity histograms and detector noise

# %% [markdown]
# Import basic routines

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.ndimage.filters import gaussian_filter
import sys

# %% [markdown]
# Import speckle related routines

# %%
sys.path.insert(0, '../scripts/')
from speckle_routines import *

# %% [markdown]
# parameters for the speckle pattern

# %%
nx,ny = 100,120 # size of array x,y
kbar = 0.5   # mean photon density (photons per pixel)
modes = 10     # number of modes in the speckle pattern
specklesize=4 # speckle size in pixel units

# %% [markdown]
# Intensity histogram of the speckle pattern

# %%
speckle = model_speckles_modes([nx,ny],specklesize,modes)
speckle /=max(speckle.flatten()) # normalise

bi,bf,db = 0.0,1.,0.1 #starting bin, final bin, bin size
hy,hx = np.histogram(speckle,bins = np.arange(bi,bf,db)) 

plt.figure(figsize = [10,3])

plt.subplot(1,2,1)
plt.imshow(speckle,interpolation='none')

plt.subplot(1,2,2)
plt.bar(hx[:-1],hy,width = db)
plt.yscale('log',nonposy='clip')
plt.xlabel('Intensity [a.u.]')
plt.ylabel('Number of pixels')
plt.show()

# %% [markdown]
# Intensity histogram of the speckle pattern with shot noise

# %%
kbar=0.05
speckle = simulate_speckles_with_shot_noise([nx,ny],modes,specklesize,kbar)
bi,bf,db = 0.0,5.,0.5
hy,hx = np.histogram(speckle,bins = np.arange(bi,bf,db)) 

plt.figure(figsize = [10,3])

plt.subplot(1,2,1)
plt.imshow(speckle,interpolation='none')

plt.subplot(1,2,2)
plt.bar(hx[:-1]-db/2.,hy,width = db)
plt.yscale('log',nonposy='clip')
plt.xlabel('Intensity [number photons]')
plt.ylabel('Number of pixels')
plt.show()

# %% [markdown]
# adding white (gaussian) noise

# %%
noise_mu,noise_sigma = 0.,0.1
noise = simulate_gaussian_noise([nx,ny],noise_mu,noise_sigma)

#speckle = simulate_speckles_with_shot_noise([nx,ny],modes,specklesize,kbar)
speckle_noise = speckle + noise

bi,bf,db = 0.0,5.,0.1
hy,hx = np.histogram(speckle_noise,bins = np.arange(bi,bf,db)) 

plt.figure(figsize = [10,3])

plt.subplot(1,2,1)
plt.imshow(speckle_noise,interpolation='none')

plt.subplot(1,2,2)
plt.bar(hx[:-1],hy,width = db)
plt.yscale('log',nonposy='clip')
plt.xlabel('Intensity [number photons]')
plt.ylabel('Number of pixels')
plt.show()

# %% [markdown]
# Gaussian bluring (intensity bleeding/charge sharing) between pixels

# %%
blur_sigma = 0.5
#speckle = simulate_speckles_with_shot_noise([nx,ny],modes,specklesize,kbar)
#speckle_blur = gaussian_filter(speckle,sigma=blur_sigma)
speckle_blur = simulate_charge_sharing(asicshape,modes,specklesize,kbar,sigma=blur_sigma)


bi,bf,db = 0.0,5.,0.1
hy,hx = np.histogram(speckle,bins = np.arange(bi,bf,db)) 
hy_blur,hx = np.histogram(speckle_blur,bins = np.arange(bi,bf,db)) 

plt.figure(figsize = [10,3])

plt.subplot(1,2,1)
plt.imshow(speckle_blur,interpolation='none')

plt.subplot(1,2,2)
plt.bar(hx[:-1],hy_blur,width = db)
plt.yscale('log',nonposy='clip')
plt.xlabel('Intensity [number photons]')
plt.ylabel('Number of pixels')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-205-1b9c21fbb7cb> in <module>()
#       2 #speckle = simulate_speckles_with_shot_noise([nx,ny],modes,specklesize,kbar)
#       3 #speckle_blur = gaussian_filter(speckle,sigma=blur_sigma)
# ----> 4 speckle_blur = simulate_charge_sharing(asicshape,modes,specklesize,kbar,sigma=blur_sigma)
#       5
#       6
#
# NameError: name 'simulate_charge_sharing' is not defined
